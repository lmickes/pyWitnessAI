# %% [markdown]
# # Using FRS for Video Identification

# %%
from pyWitnessAI import *
from pyWitnessAI import LineupLoader
# Out:
# E:\Conda\Lib\site-packages\mtcnn\mtcnn.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Load lineup memers

# %%
lineup_video1 = LineupLoader(["../data/01_Georgia_State_Video1/*Mugshot*",
                              "../data/01_Georgia_State_Video1/Video1_ProbeImage.png"],
                             innocent_suspect="../data/01_Georgia_State_Video1/Video1_Mugshot4.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 lineup_video1 = LineupLoader(["../data/01_Georgia_State_Video1/*Mugshot*",
#       2                               "../data/01_Georgia_State_Video1/Video1_ProbeImage.png"], innocent_suspect="../data/01_Georgia_State_Video1/Video1_Mugshot4.png")
#
# File D:\PhD\Software\pyWitnessAI\src\pyWitnessAI\LineupLoader.py:30, in LineupLoader.__init__(self, folder_path, guilty_suspect, innocent_suspect)
#      22 self.innocent_suspect = innocent_suspect
#      24 '''
#      25 Example of image_groups structure:
#      26 { "guilty_suspect": ["/path/Video1_Perpetrator.png"],
#      27   "innocent_suspect": ["/path/Video1_Innocent.png"],
#      28   "filler": ["/path/Filler1.png", "/path/Filler2.png", ...]}
#      29 '''
# ---> 30 self.image_groups = self._load_and_classify(folder_path)
# ...

# %% [markdown]
# When they are loaded, their `roles` (innocent suspect, guilty suspect, fillers) noted.
